# %%
import csv
import os


file_to_load = os.path.join("budget_data.csv")
file_to_output = os.path.join("budget_analysis.txt")

total_months = 0
month_of_change = []
net_change_list = []
greatest_increase = ["",0]
greatest_decrease = ["",999999999999999999999999]
total_net = 0
with open(file_to_load) as financial_data:
    reader = csv.reader(financial_data)
    header = next(reader)
    #print(header)
    first_row = next(reader)
    #print(first_row)
    total_months = total_months + 1
    total_net = total_net + int(first_row[1])
    prev_net = int(first_row[1])
   # print(total_net)
    #print(prev_net)
    
    for row in reader:
        total_months = total_months + 1
        total_net = total_net + int(row[1])

     #   print(total_net)
        net_change = int(row[1]) - prev_net
        prev_net = int(row[1])
        net_change_list = net_change_list + [net_change]
        month_of_change = month_of_change + [row[0]]
     #   print(month_of_change)
        

        if net_change > greatest_increase[1]:
            greatest_increase[0] = row[0]
            greatest_increase[1] = net_change
            
        #print(net_change_list)
        #print(month_of_change)
        

            
        if net_change < greatest_decrease[1]:
            greatest_decrease[0] = row[0]
            greatest_decrease[1] = net_change
    
        #print(net_change_list)
        print(greatest_decrease)
        net_monthly_avg = sum(net_change_list) / len(net_change_list)

    #print(net_monthly_avg)
            
        output = (
                 f"\nFinancial Analysis\n"
                 f"=======================\n"
                 f"Total Months: {total_months}\n"
                 f"Total: ${total_net}\n"
                 f"Average Change: ${net_monthly_avg:.2f}\n"
                 f"Greatest Increase In Profits  {greatest_increase[0]}, (${greatest_increase[1]})\n"
                 f"Greatest Decrease in Profits {greatest_decrease[0]}, (${greatest_decrease[1]})\n"
            
              )
        
            
        print(output)
# Out:
# ['Feb-2010', 116771]
#
# Financial Analysis
# =======================
# Total Months: 2
# Total: $1852539
# Average Change: $116771.00
# Greatest Increase In Profits  Feb-2010, ($116771)
# Greatest Decrease in Profits Feb-2010, ($116771)
#
# ['Mar-2010', -662642]
#
# Financial Analysis
# =======================
# Total Months: 3
# Total: $2174552
# Average Change: $-272935.50
# Greatest Increase In Profits  Feb-2010, ($116771)
# Greatest Decrease in Profits Mar-2010, ($-662642)
#
# ['Mar-2010', -662642]
#
# Financial Analysis
# =======================
# Total Months: 4
# Total: $2105135
# Average Change: $-312433.67
# Greatest Increase In Profits  Feb-2010, ($116771)
# Greatest Decrease in Profits Mar-2010, ($-662642)
#
# ['Mar-2010', -662642]
#
# Financial Analysis
# =======================
# Total Months: 5
# Total: $2415638
# Average Change: $-139345.25
# Greatest Increase In Profits  May-2010, ($379920)
# Greatest Decrease in Profits Mar-2010, ($-662642)
#
# ['Mar-2010', -662642]
#
# Financial Analysis
# =======================
# Total Months: 6
# Total: $2938495
# Average Change: $-69005.40
# Greatest Increase In Profits  May-2010, ($379920)
# Greatest Decrease in Profits Mar-2010, ($-662642)
#
# ['Mar-2010', -662642]
#
# Financial Analysis
# =======================
# Total Months: 7
# Total: $3971591
# Average Change: $27535.33
# Greatest Increase In Profits  Jul-2010, ($510239)
# Greatest Decrease in Profits Mar-2010, ($-662642)
#
# ['Mar-2010', -662642]
#
# Financial Analysis
# =======================
# Total Months: 8
# Total: $4576476
# Average Change: $-37571.29
# Greatest Increase In Profits  Jul-2010, ($510239)
# Greatest Decrease in Profits Mar-2010, ($-662642)
#
# ['Sep-2010', -821271]
#
# Financial Analysis
# =======================
# Total Months: 9
# Total: $4360090
# Average Change: $-135533.75
# Greatest Increase In Profits  Jul-2010, ($510239)
# Greatest Decrease in Profits Sep-2010, ($-821271)
#
# ['Sep-2010', -821271]
#
# Financial Analysis
# =======================
# Total Months: 10
# Total: $4837622
# Average Change: $-43372.44
# Greatest Increase In Profits  Oct-2010, ($693918)
# Greatest Decrease in Profits Sep-2010, ($-821271)
#
# ['Sep-2010', -821271]
#
# Financial Analysis
# =======================
# Total Months: 11
# Total: $5731432
# Average Change: $2592.60
# Greatest Increase In Profits  Oct-2010, ($693918)
# Greatest Decrease in Profits Sep-2010, ($-821271)
#
# ['Dec-2010', -974163]
#
# Financial Analysis
# =======================
# Total Months: 12
# Total: $5651079
# Average Change: $-86203.36
# Greatest Increase In Profits  Oct-2010, ($693918)
# Greatest Decrease in Profits Dec-2010, ($-974163)
#
# ['Dec-2010', -974163]
#
# Financial Analysis
# =======================
# Total Months: 13
# Total: $6430885
# Average Change: $-7339.83
# Greatest Increase In Profits  Jan-2011, ($860159)
# Greatest Decrease in Profits Dec-2010, ($-974163)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 14
# Total: $6095682
# Average Change: $-92545.15
# Greatest Increase In Profits  Jan-2011, ($860159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 15
# Total: $6793527
# Average Change: $-12145.64
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 16
# Total: $7586690
# Average Change: $-4981.40
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 17
# Total: $8071760
# Average Change: $-23925.88
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 18
# Total: $8655882
# Average Change: $-16691.88
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 19
# Total: $8718611
# Average Change: $-44730.83
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 20
# Total: $9386790
# Average Change: $-10510.79
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 21
# Total: $10286696
# Average Change: $1601.10
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 22
# Total: $11121415
# Average Change: $-1579.29
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 23
# Total: $11253418
# Average Change: $-33449.14
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 24
# Total: $11563396
# Average Change: $-24256.78
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 25
# Total: $10807830
# Average Change: $-67643.75
# Greatest Increase In Profits  Mar-2011, ($1033048)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 26
# Total: $11978423
# Average Change: $12108.36
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 27
# Total: $12231211
# Average Change: $-23657.54
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 28
# Total: $13382729
# Average Change: $10504.96
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 29
# Total: $14199985
# Average Change: $-1808.14
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 30
# Total: $14770742
# Average Change: $-10245.76
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Feb-2011', -1115009]
#
# Financial Analysis
# =======================
# Total Months: 31
# Total: $15277444
# Average Change: $-12039.40
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Feb-2011, ($-1115009)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 32
# Total: $14254910
# Average Change: $-60981.23
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 33
# Total: $14729972
# Average Change: $-12275.69
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 34
# Total: $15509948
# Average Change: $-2663.88
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 35
# Total: $15654123
# Average Change: $-21285.56
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 36
# Total: $16196617
# Average Change: $-9296.86
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 37
# Total: $16555950
# Average Change: $-14126.42
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 38
# Total: $16877419
# Average Change: $-14767.97
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 39
# Total: $16945199
# Average Change: $-21055.37
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 40
# Total: $17416634
# Average Change: $-10165.36
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 41
# Total: $17982237
# Average Change: $-7557.02
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 42
# Total: $18854717
# Average Change: $112.10
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 43
# Total: $19644197
# Average Change: $-1866.76
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Aug-2012', -1529236]
#
# Financial Analysis
# =======================
# Total Months: 44
# Total: $20644139
# Average Change: $3071.12
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Aug-2012, ($-1529236)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 45
# Total: $19447914
# Average Change: $-46911.57
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 46
# Total: $19716911
# Average Change: $-13308.60
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 47
# Total: $19028925
# Average Change: $-33823.26
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 48
# Total: $20179386
# Average Change: $6012.28
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 49
# Total: $20861844
# Average Change: $-3863.04
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 50
# Total: $21479700
# Average Change: $-5102.61
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 51
# Total: $22303798
# Average Change: $-875.72
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 52
# Total: $22885741
# Average Change: $-5606.69
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 53
# Total: $23018605
# Average Change: $-14135.00
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 54
# Total: $23466667
# Average Change: $-7921.17
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 55
# Total: $24155828
# Average Change: $-3309.69
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 56
# Total: $24956529
# Average Change: $-1221.51
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 57
# Total: $26123172
# Average Change: $5334.98
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 58
# Total: $27070505
# Average Change: $1393.84
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 59
# Total: $27649173
# Average Change: $-4986.48
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 60
# Total: $28637678
# Average Change: $2044.42
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 61
# Total: $29777393
# Average Change: $4530.52
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 62
# Total: $30806864
# Average Change: $2648.97
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 63
# Total: $31494397
# Average Change: $-2908.89
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 64
# Total: $30969771
# Average Change: $-22103.33
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 65
# Total: $31128391
# Average Change: $-11082.25
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 66
# Total: $31216186
# Average Change: $-12001.37
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 67
# Total: $31639575
# Average Change: $-6734.77
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 68
# Total: $32480298
# Average Change: $-405.39
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 69
# Total: $33048827
# Average Change: $-4402.28
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 70
# Total: $33380894
# Average Change: $-7765.46
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 71
# Total: $34370393
# Average Change: $1737.36
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 72
# Total: $35148630
# Average Change: $-1262.63
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 73
# Total: $35798630
# Average Change: $-3026.17
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 74
# Total: $34698243
# Average Change: $-26962.62
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 75
# Total: $34523297
# Average Change: $-14092.30
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 76
# Total: $35280440
# Average Change: $-1476.55
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 77
# Total: $35726149
# Average Change: $-5554.93
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 78
# Total: $36439110
# Average Change: $-2011.99
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 79
# Total: $35275313
# Average Change: $-26047.19
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 80
# Total: $35845212
# Average Change: $-3771.96
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 81
# Total: $36613662
# Average Change: $-1242.92
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 82
# Total: $36716347
# Average Change: $-9446.90
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 83
# Total: $37512261
# Average Change: $-877.68
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 84
# Total: $37573249
# Average Change: $-9721.64
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 85
# Total: $37711479
# Average Change: $-8686.36
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
#
# ['Sep-2013', -2196167]
#
# Financial Analysis
# =======================
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase In Profits  Feb-2012, ($1926159)
# Greatest Decrease in Profits Sep-2013, ($-2196167)
